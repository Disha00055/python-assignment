# %%
'''
import pandas as pd

# Given dataframe
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2, 3, 6, 4]
df = pd.DataFrame(data={'course_name': course_name, 'duration': duration})

# Q1. Code to print data present in the second row of the dataframe, df.
print(df.iloc[1])

# Q2. Difference between loc and iloc in pandas.DataFrame:
# loc is label-based indexing while iloc is integer-based indexing.

# Q3. Reindex the given dataframe and find the output for new_df.loc[2] and new_df.iloc[2].
reindex = [3, 0, 1, 2]
new_df = df.reindex(reindex)
print(new_df.loc[2])
print(new_df.iloc[2])

# Q4. Statistical measurements for the dataframe df:
# (i) mean of each column
print(df.mean())
# (ii) standard deviation of column 'duration'
print(df['duration'].std())

# Q5. Replace data in the second row of column 'duration' with a string variable
df.loc[1, 'duration'] = 'string data'
# Calculate the mean of column 'duration'
# This will raise an error since the column contains string data, which cannot be used to calculate the mean.
print(df['duration'].mean())

# Q6. Windows function in pandas and types of windows functions:
# Windows functions operate on a set of rows and return a single value for each row.
# Types include rolling, expanding, and ewm (exponentially weighted moving).

# Q7. Code to print only the current month and year.
current_date = pd.datetime.now()
print(current_date.strftime("%B %Y"))

# Q8. Python program to calculate the difference between two dates.
from datetime import datetime
date1_str = input("Enter the first date (YYYY-MM-DD): ")
date2_str = input("Enter the second date (YYYY-MM-DD): ")

date_format = "%Y-%m-%d"
date1 = datetime.strptime(date1_str, date_format)
date2 = datetime.strptime(date2_str, date_format)

# Calculate the difference
difference = date2 - date1
print("Difference:", difference)
```

```python
import pandas as pd
import numpy as np

# Given dataframe
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1, 2, 3, 4, 5, 6]
df1 = pd.DataFrame(np.random.rand(6, 6), columns=columns, index=indices)

# Q9. Python program to read a CSV file containing categorical data and convert a specified column to a categorical data type.
file_path = input("Enter the file path: ")
column_name = input("Enter the column name to convert to categorical: ")
category_order = input("Enter the category order (comma-separated): ").split(',')

# Read CSV file
df = pd.read_csv(file_path)

# Convert column to categorical data type
df[column_name] = pd.Categorical(df[column_name], categories=category_order, ordered=True)

# Sort data
sorted_data = df.sort_values(by=column_name)
print(sorted_data)

# Q10. Python program to read a CSV file containing sales data for different products and visualize the data using a stacked bar chart.
import matplotlib.pyplot as plt

file_path = input("Enter the file path: ")
df = pd.read_csv(file_path)

# Assume the CSV file contains columns 'Date', 'Product', and 'Sales'
# Pivot the data
pivot_df = df.pivot(index='Date', columns='Product', values='Sales')

# Plot stacked bar chart
pivot_df.plot(kind='bar', stacked=True)
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales of Products Over Time')
plt.show()

# Q11. Python program to calculate mean, median, and mode of test scores in a CSV file containing student data.
file_path = input("Enter the file path: ")
df = pd.read_csv(file_path)

# Calculate statistics
mean_score = df['Test Score'].mean()
median_score = df['Test Score'].median()
mode_score = df['Test Score'].mode()

# Display results in a table
statistics_df = pd.DataFrame({'Statistic': ['Mean', 'Median', 'Mode'],
                              'Value': [mean_score, median_score, mode_score]})
print(statistics_df)
'''
